# %% [markdown]
# <a href="https://colab.research.google.com/github/anisbagwan/Student-evaluation/blob/main/Score_preditcion_of_students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![TSF.png](data:image/png;base64,...)

# %% [markdown]
# # Let's create the dataframe of students

# %%
# import pandas library
import pandas as pd

# %%
students={'Hours':[2.5,5.1,3.2,8.5,3.5,1.5,9.2,5.5,8.3,2.7,7.7,5.9,4.5,3.3,
                   1.1,8.9,2.5,1.9,6.1,7.4,2.7,4.8,3.8,6.9,7.8],
          'Scores':[21,47,27,75,30,20,88,60,81,25,85,62,41,42,17,95,30,24,67,69,
                    30,54,35,76,86]}

# %%
# creating a Dataframe object 
df = pd.DataFrame(students)

# %%
df.tail()
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86
